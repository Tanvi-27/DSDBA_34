# %%
import pandas as pd
import numpy as np

df = pd.read_excel("/home/ubuntu/Documents/TCOB34/student_information.xlsx")
df
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 0         67.0           89.0             63             92.0            2021
# 1         80.0           81.0             69             95.0            2020
# 2         78.0           94.0             78             90.0            2020
# 3         60.0           75.0             60            100.0            2019
# 4         71.0           95.0             64             89.0            2021
# 5         79.0           77.0             71             93.0            2020
# 6         77.0           78.0             78             93.0            2021
# 7          NaN           93.0             73             92.0            2019
# 8         72.0           92.0             69             82.0            2018
# 9         77.0           91.0             68             99.0            2021
# 10        64.0           84.0             74             81.0            2019
# ...

# %%
df.isnull()
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 0        False          False          False            False           False
# 1        False          False          False            False           False
# 2        False          False          False            False           False
# 3        False          False          False            False           False
# 4        False          False          False            False           False
# 5        False          False          False            False           False
# 6        False          False          False            False           False
# 7         True          False          False            False           False
# 8        False          False          False            False           False
# 9        False          False          False            False           False
# 10       False          False          False            False           False
# ...

# %%
series = pd.isnull(df["Math_Score"])
df[series]
# Out:
#    Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 7         NaN           93.0             73             92.0            2019
#
#    Placement_Offer_Count
# 7                    2.0

# %%
df.notnull()
# Out:
#     math score  reading score  writing score  placement score  club join date  \
# 0         True           True           True             True            True
# 1         True           True           True             True            True
# 2         True           True           True             True            True
# 3         True           True           True             True            True
# 4         True           True           True             True            True
# 5         True           True           True             True            True
# 6         True           True           True             True            True
# 7         True           True           True             True            True
# 8         True           True           True             True            True
# 9         True           True           True             True            True
# 10        True           True           True             True            True
# ...

# %%
series1 = pd.notnull(df["Math_Score"])
df[series1]
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 0         67.0           89.0             63             92.0            2021
# 1         80.0           81.0             69             95.0            2020
# 2         78.0           94.0             78             90.0            2020
# 3         60.0           75.0             60            100.0            2019
# 4         71.0           95.0             64             89.0            2021
# 5         79.0           77.0             71             93.0            2020
# 6         77.0           78.0             78             93.0            2021
# 8         72.0           92.0             69             82.0            2018
# 9         77.0           91.0             68             99.0            2021
# 10        64.0           84.0             74             81.0            2019
# 11        74.0           94.0             66             85.0            2019
# ...

# %%
missing_values = ["NaN", "nan"]
df = pd.read_excel("/home/ubuntu/Documents/TCOB34/student_information.xlsx", na_values = missing_values)
df
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 0         67.0           89.0             63             92.0            2021
# 1         80.0           81.0             69             95.0            2020
# 2         78.0           94.0             78             90.0            2020
# 3         60.0           75.0             60            100.0            2019
# 4         71.0           95.0             64             89.0            2021
# 5         79.0           77.0             71             93.0            2020
# 6         77.0           78.0             78             93.0            2021
# 7          NaN           93.0             73             92.0            2019
# 8         72.0           92.0             69             82.0            2018
# 9         77.0           91.0             68             99.0            2021
# 10        64.0           84.0             74             81.0            2019
# ...

# %%
ndf=df
ndf.fillna(0)
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 0         67.0           89.0             63             92.0            2021
# 1         80.0           81.0             69             95.0            2020
# 2         78.0           94.0             78             90.0            2020
# 3         60.0           75.0             60            100.0            2019
# 4         71.0           95.0             64             89.0            2021
# 5         79.0           77.0             71             93.0            2020
# 6         77.0           78.0             78             93.0            2021
# 7          0.0           93.0             73             92.0            2019
# 8         72.0           92.0             69             82.0            2018
# 9         77.0           91.0             68             99.0            2021
# 10        64.0           84.0             74             81.0            2019
# ...

# %%
m_v=df['Math_Score'].mean()
df['Math_Score'].fillna(value=m_v, inplace=True)
df
# Out:
# /tmp/ipykernel_5798/578764738.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Math_Score'].fillna(value=m_v, inplace=True)
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 0    67.000000           89.0             63             92.0            2021
# 1    80.000000           81.0             69             95.0            2020
# 2    78.000000           94.0             78             90.0            2020
# ...

# %%
ndf.replace(to_replace = -99, value = "NaN")
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 0    67.000000           89.0             63             92.0            2021
# 1    80.000000           81.0             69             95.0            2020
# 2    78.000000           94.0             78             90.0            2020
# 3    60.000000           75.0             60            100.0            2019
# 4    71.000000           95.0             64             89.0            2021
# 5    79.000000           77.0             71             93.0            2020
# 6    77.000000           78.0             78             93.0            2021
# 7    72.931034           93.0             73             92.0            2019
# 8    72.000000           92.0             69             82.0            2018
# 9    77.000000           91.0             68             99.0            2021
# 10   64.000000           84.0             74             81.0            2019
# ...

# %%
ndf.dropna()
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 0    67.000000           89.0             63             92.0            2021
# 1    80.000000           81.0             69             95.0            2020
# 2    78.000000           94.0             78             90.0            2020
# 3    60.000000           75.0             60            100.0            2019
# 4    71.000000           95.0             64             89.0            2021
# 5    79.000000           77.0             71             93.0            2020
# 6    77.000000           78.0             78             93.0            2021
# 7    72.931034           93.0             73             92.0            2019
# 8    72.000000           92.0             69             82.0            2018
# 9    77.000000           91.0             68             99.0            2021
# 10   64.000000           84.0             74             81.0            2019
# ...

# %%
df=pd.read_excel("/home/ubuntu/Desktop/TCOB42/Student_Data1.xlsx")
df
# Out:
#     math score  reading score  writing score placement score  club join date  \
# 0         70.0             88           76.0              77          2020.0
# 1         78.0             94           60.0             100          2018.0
# 2         62.0             76           73.0              75          2020.0
# 3         71.0             84           66.0              90          2018.0
# 4         78.0             85           71.0              96          2018.0
# 5         60.0             76           68.0              98          2018.0
# 6         75.0             77            NaN              95             NaN
# 7         70.0             76           60.0              82          2018.0
# 8         55.0             75           88.0              80          2019.0
# 9         79.0             93           72.0              98          2020.0
# 10        73.0             81           77.0              76          2020.0
# ...

# %%
ndf=df

# %%
ndf.dropna(how = 'all')
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 0    67.000000           89.0             63             92.0            2021
# 1    80.000000           81.0             69             95.0            2020
# 2    78.000000           94.0             78             90.0            2020
# 3    60.000000           75.0             60            100.0            2019
# 4    71.000000           95.0             64             89.0            2021
# 5    79.000000           77.0             71             93.0            2020
# 6    77.000000           78.0             78             93.0            2021
# 7    72.931034           93.0             73             92.0            2019
# 8    72.000000           92.0             69             82.0            2018
# 9    77.000000           91.0             68             99.0            2021
# 10   64.000000           84.0             74             81.0            2019
# ...

# %%
ndf.dropna(axis = 1)
# Out:
#     reading score placement score  placement offer count
# 0              88              77                      2
# 1              94             100                      3
# 2              76              75                      2
# 3              84              90                      3
# 4              85              96                      3
# 5              76              98                      3
# 6              77              95                      3
# 7              76              82                      2
# 8              75              80                      2
# 9              93              98                      3
# 10             81              76                      2
# 11             79              93                      3
# 12             84              79                      2
# 13             93              96                      3
# 14             85              82                      2
# ...

# %%
new_data = ndf.dropna(axis = 0, how ='any')
new_data
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 0    67.000000           89.0             63             92.0            2021
# 1    80.000000           81.0             69             95.0            2020
# 2    78.000000           94.0             78             90.0            2020
# 3    60.000000           75.0             60            100.0            2019
# 4    71.000000           95.0             64             89.0            2021
# 5    79.000000           77.0             71             93.0            2020
# 6    77.000000           78.0             78             93.0            2021
# 7    72.931034           93.0             73             92.0            2019
# 8    72.000000           92.0             69             82.0            2018
# 9    77.000000           91.0             68             99.0            2021
# 10   64.000000           84.0             74             81.0            2019
# ...
